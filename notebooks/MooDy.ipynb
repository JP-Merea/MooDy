# %%
#pip install wordcloud

# %%
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import string

# %%
df = pd.read_csv("tweets.csv")

# %%
df.head().T
# Out:
#                                                                             0  \
# coordinates                                                               NaN
# created_at                                     Mon Apr 27 00:36:15 +0000 2020
# hashtags                                                                  NaN
# media                                                                     NaN
# urls                                                     http://m.uy/uc751169
# favorite_count                                                              0
# id                                                        1254570018089635840
# in_reply_to_screen_name                                                   NaN
# in_reply_to_status_id                                                     NaN
# in_reply_to_user_id                                                       NaN
# lang                                                                       es
# ...

# %%
df.describe()
# Out:
#                       coordinates  created_at  hashtags   media  \
# count                        4582     1096820    222015  255111
# unique                        777     1067837     84283  253188
# top     -58.95890236,-34.16022905  created_at  Covid_19   media
# freq                          619         487      4914     487
#
#                                                     urls favorite_count  \
# count                                             537223        1096820
# unique                                            444940           2750
# top     https://twitter.com/i/events/1219057585707315201              0
# freq                                                1677         492465
#
#              id  in_reply_to_screen_name  in_reply_to_status_id  \
# count   1096820                      487                    487
# unique  1094165                        1                      1
# top          id  in_reply_to_screen_name  in_reply_to_status_id
# ...

# %%
df.count()
# Out:
# coordinates                      4582
# created_at                    1096820
# hashtags                       222015
# media                          255111
# urls                           537223
# favorite_count                1096820
# id                            1096820
# in_reply_to_screen_name           487
# in_reply_to_status_id             487
# in_reply_to_user_id               487
# lang                          1096820
# place                           79905
# possibly_sensitive             671137
# quote_id                        92543
# retweet_count                 1096820
# retweet_id                        487
# retweet_screen_name               487
# source                        1096820
# text                          1096820
# tweet_url                     1096820
# user_created_at               1096820
# user_id                       1096820
# user_default_profile_image    1096820
# user_description              1012818
# user_favourites_count         1096820
# ...

# %%
df.info(verbose=True, null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1096820 entries, 0 to 1096819
# Data columns (total 35 columns):
#  #   Column                      Non-Null Count    Dtype
# ---  ------                      --------------    -----
#  0   coordinates                 4582 non-null     object
#  1   created_at                  1096820 non-null  object
#  2   hashtags                    222015 non-null   object
#  3   media                       255111 non-null   object
#  4   urls                        537223 non-null   object
#  5   favorite_count              1096820 non-null  object
#  6   id                          1096820 non-null  object
#  7   in_reply_to_screen_name     487 non-null      object
#  8   in_reply_to_status_id       487 non-null      object
#  9   in_reply_to_user_id         487 non-null      object
#  10  lang                        1096820 non-null  object
#  11  place                       79905 non-null    object
# ...

# %%
df.isna().sum()
# Out:
# coordinates                   1092238
# created_at                          0
# hashtags                       874805
# media                          841709
# urls                           559597
# favorite_count                      0
# id                                  0
# in_reply_to_screen_name       1096333
# in_reply_to_status_id         1096333
# in_reply_to_user_id           1096333
# lang                                0
# place                         1016915
# possibly_sensitive             425683
# quote_id                      1004277
# retweet_count                       0
# retweet_id                    1096333
# retweet_screen_name           1096333
# source                              0
# text                                0
# tweet_url                           0
# user_created_at                     0
# user_id                             0
# user_default_profile_image          0
# user_description                84002
# user_favourites_count               0
# ...

# %%
fd = df[['created_at',
    'urls',
    'hashtags',
    'user_favourites_count',
    'retweet_count',
    'user_followers_count',
    'user_screen_name',
    'user_name',
    'user_verified',
    'text']]

# %%
fd.tail()
# Out:
#                              created_at  \
# 1096815  Wed Sep 01 23:39:08 +0000 2021
# 1096816  Wed Sep 01 23:52:28 +0000 2021
# 1096817  Wed Sep 01 23:58:16 +0000 2021
# 1096818  Wed Sep 01 23:44:29 +0000 2021
# 1096819  Wed Sep 01 23:57:46 +0000 2021
#
#                                                       urls hashtags  \
# 1096815  https://twitter.com/Jabaluck/status/1433036923...      NaN
# 1096816                                                NaN      NaN
# 1096817                                                NaN      NaN
# 1096818  https://noticias.vtv.com.uy/covid-19-en-urugua...      NaN
# 1096819                                                NaN      NaN
#
#         user_favourites_count retweet_count user_followers_count  \
# 1096815                  5407             1                 2853
# 1096816                167530             2                 5256
# 1096817                  3164             0                  813
# ...

# %%
df = fd.sort_values(by ='user_favourites_count', ascending = False)
df
# Out:
#                              created_at  \
# 1020266                      created_at
# 1005818                      created_at
# 247389                       created_at
# 1077406                      created_at
# 343203                       created_at
# ...                                 ...
# 985867   Tue Jun 22 11:41:19 +0000 2021
# 411297   Mon Oct 26 00:29:33 +0000 2020
# 411282   Mon Oct 26 00:27:44 +0000 2020
# 1080753  Wed Aug 18 16:00:55 +0000 2021
# 153283   Sun Jul 05 13:53:19 +0000 2020
#
#                                                       urls  hashtags  \
# 1020266                                               urls  hashtags
# 1005818                                               urls  hashtags
# 247389                                                urls  hashtags
# 1077406                                               urls  hashtags
# 343203                                                urls  hashtags
# ...

# %%
df = df.loc[(df["created_at"] != 'created_at')]

# %%
df.sort_values(by ='user_followers_count', ascending = False).head(10)
# Out:
#                              created_at  \
# 1039652  Tue Jul 20 16:19:00 +0000 2021
# 31534    Sun May 10 13:46:05 +0000 2020
# 800762   Sun Apr 18 00:48:00 +0000 2021
# 181232   Sun Jul 19 01:02:04 +0000 2020
# 1036510  Mon Jul 19 00:08:52 +0000 2021
# 820029   Fri Apr 23 13:31:00 +0000 2021
# 817356   Thu Apr 22 18:42:00 +0000 2021
# 1031967  Fri Jul 16 11:29:01 +0000 2021
# 1016312  Thu Jul 08 11:29:47 +0000 2021
# 10235    Tue Apr 28 18:42:00 +0000 2020
#
#                                                       urls  \
# 1039652    https://digitaltv.prensariozone.com/bitcentral/
# 31534    https://www.forbes.com/sites/lisettevoytko/202...
# 800762                                                 NaN
# 181232                                                 NaN
# 1036510                                                NaN
# 820029   https://digitaltv.prensariozone.com/nextv-seri...
# 817356   https://digitaltv.prensariozone.com/nextv-seri...
# ...

# %%
df.dtypes
# Out:
# created_at               object
# urls                     object
# hashtags                 object
# user_favourites_count    object
# retweet_count            object
# user_followers_count     object
# user_screen_name         object
# user_name                object
# user_verified            object
# text                     object
# dtype: object

# %%
df.loc[:, 'created_at'] = pd.to_datetime(df['created_at'])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/9t/4q21kp8s6vb49kb4fvt2l39h0000gn/T/ipykernel_37817/516867773.py in <module>
# ----> 1 df.loc[:, 'created_at'] = pd.to_datetime(df['created_at'])
#
# ~/.pyenv/versions/3.8.6/envs/MooDy/lib/python3.8/site-packages/pandas/core/tools/datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#     885             result = arg.map(cache_array)
#     886         else:
# --> 887             values = convert_listlike(arg._values, format)
#     888             result = arg._constructor(values, index=arg.index, name=arg.name)
#     889     elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# ...

# %%
df.dtypes

# %%
df['user_favourites_count'] = df.user_favourites_count.astype(int)

# %%
df.dtypes

# %%
df['user_followers_count'] = df.user_followers_count.astype(int)

# %%
df.dtypes

# %%
df['user_screen_name'] = df.user_screen_name.astype(str)

# %%
df.dtypes
